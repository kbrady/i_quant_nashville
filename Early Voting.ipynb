# %% [markdown]
# ** Load a csv of locations you want to view. **
#
# **The first column should be the name and the second column should be the address.**

# %%
# to import csvs
import pandas as pd
# to create javascript map
import map_scripts
# to render html
from IPython.display import HTML

# the data
data = pd.read_csv('early_voting.csv')
data.head()
# Out:
#                               Name  \
# 0            Belle Meade City Hall
# 1        Bellevue Community Center
# 2                 Bordeaux Library
# 3    Casa Azafran Community Center
# 4  Goodlettsville Community Center
#
#                                       Location
# 0       4705 Harding Pike, Nashville, TN 37205
# 1  656 Coice Jeannie Road, Nashville, TN 37221
# 2   4000 Clarksville Pike, Nashville, TN 37218
# 3   2195 Nolensville Pike, Nashville, TN 37211
# 4    200 Memorial Dr, Goodlettsville, TN 37072

# %% [markdown]
# ** Put your address in the box bellow to find the closest early voting place to you **

# %%
HTML(map_scripts.plot_markers(data))
# Out:
# 		<style>
# 				html, body {
# 					height: 100%;
# 					margin: 0;
# 					padding: 0;
# 				}
# 				#map {
# 					height: 500px;
# 					margin-right: 400px;
# 				}
# 				#floating-Panel {
# 					position: absolute;
# 					top: 10px;
# 					left: 25%;
# 					z-index: 5;
# 					background-color: #fff;
# 					padding: 5px;
# 					border: 1px solid #999;
# 					text-align: center;
# 					font-family: 'Roboto','sans-serif';
# 					line-height: 30px;
# 					padding-left: 10px;
# 					background: #fff;
# 					padding: 5px;
# 					font-size: 14px;
# 					font-family: Arial;
# 					border: 1px solid #ccc;
# 					box-shadow: 0 2px 2px rgba(33, 33, 33, 0.4);
# 				}
# 				#directions-Panel {
# 					font-family: 'Roboto','sans-serif';
# 					line-height: 30px;
# 					padding-left: 10px;
# 					height: 500px;
# 					float: right;
# 					width: 390px;
# 					overflow: auto;
# 				}
# 				#directions-Panel select, #directions-Panel input {
# 					font-size: 15px;
# 				}
#
# ...
